# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
import time
from scipy.stats import linregress

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %%
# to get a list of settable variable properties
# plt.setp(variable)

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
# Uniformly distributed means that the probability of generating a number within 
# any given range of values is proportional to the length of that range
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# print(cities)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 627

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
# i is index number of city in cities list
# enumerate() function iterates over a sequence and generates pairs of (index, fruit) for each element
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0
        
    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&q={city}&units={units}"

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1
    
    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
        
    # If an error is experienced, skip the city                      
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")

# break
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hauterive
# Processing Record 2 of Set 1 | fortuna foothills
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 5 of Set 1 | corn island
# Processing Record 6 of Set 1 | olafsvik
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | vardo
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | yar-sale
# Processing Record 11 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | nikolskoye
# Processing Record 14 of Set 1 | tanhacu
# Processing Record 15 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 16 of Set 1 | akyab
# Processing Record 17 of Set 1 | ous
# Processing Record 18 of Set 1 | praia da vitoria
# Processing Record 19 of Set 1 | kovur
# Processing Record 20 of Set 1 | ostersund
# Processing Record 21 of Set 1 | mataura
# Processing Record 22 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 23 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 24 of Set 1 | clyde river
# Processing Record 25 of Set 1 | victoria
# Processing Record 26 of Set 1 | vilhena
# Processing Record 27 of Set 1 | port hedland
# Processing Record 28 of Set 1 | japura
# Processing Record 29 of Set 1 | saskylakh
# Processing Record 30 of Set 1 | airai
# Processing Record 31 of Set 1 | avarua
# Processing Record 32 of Set 1 | inuvik
# Processing Record 33 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 34 of Set 1 | port alfred
# Processing Record 35 of Set 1 | praya
# Processing Record 36 of Set 1 | osa
# Processing Record 37 of Set 1 | nhulunbuy
# Processing Record 38 of Set 1 | karakol
# Processing Record 39 of Set 1 | hobart
# Processing Record 40 of Set 1 | severo-yeniseyskiy
# Processing Record 41 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 42 of Set 1 | barkly west
# Processing Record 43 of Set 1 | esmeralda
# Processing Record 44 of Set 1 | mahebourg
# Processing Record 45 of Set 1 | iqaluit
# Processing Record 46 of Set 1 | coari
# Processing Record 47 of Set 1 | vila velha
# Processing Record 48 of Set 1 | atuona
# Processing Record 49 of Set 1 | castro
# Processing Record 50 of Set 1 | ushuaia
# Processing Record 0 of Set 2 | moyale
# Processing Record 1 of Set 2 | klaksvik
# Processing Record 2 of Set 2 | cayenne
# Processing Record 3 of Set 2 | tokur
# Processing Record 4 of Set 2 | sao miguel do araguaia
# Processing Record 5 of Set 2 | komsomolskiy
# Processing Record 6 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 2 | bluff
# Processing Record 8 of Set 2 | moree
# Processing Record 9 of Set 2 | puerto del rosario
# Processing Record 10 of Set 2 | new norfolk
# Processing Record 11 of Set 2 | hilo
# Processing Record 12 of Set 2 | taguatinga
# Processing Record 13 of Set 2 | torbay
# Processing Record 14 of Set 2 | tiksi
# Processing Record 15 of Set 2 | milingimbi
# City not found. Skipping...
# Processing Record 16 of Set 2 | taybad
# Processing Record 17 of Set 2 | andapa
# Processing Record 18 of Set 2 | upernavik
# Processing Record 19 of Set 2 | kodiak
# Processing Record 20 of Set 2 | poum
# Processing Record 21 of Set 2 | kirakira
# Processing Record 22 of Set 2 | babu
# Processing Record 23 of Set 2 | tidore
# City not found. Skipping...
# Processing Record 24 of Set 2 | wenling
# Processing Record 25 of Set 2 | hermanus
# Processing Record 26 of Set 2 | ahipara
# Processing Record 27 of Set 2 | kalga
# Processing Record 28 of Set 2 | nanortalik
# Processing Record 29 of Set 2 | jamestown
# Processing Record 30 of Set 2 | inhuma
# Processing Record 31 of Set 2 | saint-augustin
# Processing Record 32 of Set 2 | east london
# Processing Record 33 of Set 2 | bredasdorp
# Processing Record 34 of Set 2 | chlorakas
# Processing Record 35 of Set 2 | bam
# Processing Record 36 of Set 2 | fernandina beach
# Processing Record 37 of Set 2 | phan rang
# City not found. Skipping...
# Processing Record
of Set 4 | alotau
# City not found. Skipping...
# Processing Record 26 of Set 4 | kundiawa
# Processing Record 27 of Set 4 | kaitangata
# Processing Record 28 of Set 4 | saldanha
# Processing Record 29 of Set 4 | sabha
# Processing Record 30 of Set 4 | sao filipe
# Processing Record 31 of Set 4 | middlebury
# Processing Record 32 of Set 4 | umm lajj
# Processing Record 33 of Set 4 | pisco
# Processing Record 34 of Set 4 | gogrial
# Processing Record 35 of Set 4 | taunsa
# Processing Record 36 of Set 4 | eureka
# Processing Record 37 of Set 4 | rabat
# Processing Record 38 of Set 4 | salinopolis
# Processing Record 39 of Set 4 | pangody
# Processing Record 40 of Set 4 | caravelas
# Processing Record 41 of Set 4 | denau
# City not found. Skipping...
# Processing Record 42 of Set 4 | yenagoa
# Processing Record 43 of Set 4 | hay river
# Processing Record 44 of Set 4 | petatlan
# Processing Record 45 of Set 4 | kaihua
# Processing Record 46 of Set 4 | shiringushi
# Processing Record 47 of Set 4 | mizdah
# Processing Record 48 of Set 4 | kibala
# Processing Record 49 of Set 4 | erenhot
# Processing Record 0 of Set 5 | hithadhoo
# Processing Record 1 of Set 5 | pangkalanbuun
# Processing Record 2 of Set 5 | lagoa
# Processing Record 3 of Set 5 | gazli
# Processing Record 4 of Set 5 | saint-francois
# Processing Record 5 of Set 5 | chapais
# Processing Record 6 of Set 5 | krasnoarmeysk
# Processing Record 7 of Set 5 | sol-iletsk
# Processing Record 8 of Set 5 | lazaro cardenas
# Processing Record 9 of Set 5 | bahawalpur
# Processing Record 10 of Set 5 | sidi bu zayd
# City not found. Skipping...
# Processing Record 11 of Set 5 | san cristobal
# Processing Record 12 of Set 5 | isangel
# Processing Record 13 of Set 5 | la ronge
# Processing Record 14 of Set 5 | yellowknife
# Processing Record 15 of Set 5 | san patricio
# Processing Record 16 of Set 5 | hambantota
# Processing Record 17 of Set 5 | pemba
# Processing Record 18 of Set 5 | kahului
# Processing Record 19 of Set 5 | cherskiy
# Processing Record 20 of Set 5 | kiomboi
# Processing Record 21 of Set 5 | yulara
# Processing Record 22 of Set 5 | nyurba
# Processing Record 23 of Set 5 | lasa
# Processing Record 24 of Set 5 | nioro
# Processing Record 25 of Set 5 | estevan
# Processing Record 26 of Set 5 | bosobolo
# Processing Record 27 of Set 5 | acapulco
# Processing Record 28 of Set 5 | fort-shevchenko
# Processing Record 29 of Set 5 | betare oya
# Processing Record 30 of Set 5 | sarh
# Processing Record 31 of Set 5 | ontario
# Processing Record 32 of Set 5 | icatu
# Processing Record 33 of Set 5 | waipawa
# Processing Record 34 of Set 5 | narsaq
# Processing Record 35 of Set 5 | panzhihua
# Processing Record 36 of Set 5 | aklavik
# Processing Record 37 of Set 5 | huangpu
# Processing Record 38 of Set 5 | calama
# Processing Record 39 of Set 5 | drezdenko
# Processing Record 40 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 41 of Set 5 | wa
# City not found. Skipping...
# Processing Record 42 of Set 5 | ola
# Processing Record 43 of Set 5 | dobryanka
# Processing Record 44 of Set 5 | mareeba
# Processing Record 45 of Set 5 | beringovskiy
# Processing Record 46 of Set 5 | meadow lake
# Processing Record 47 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 5 | gushikawa
# Processing Record 49 of Set 5 | geraldton
# Processing Record 0 of Set 6 | saint george
# Processing Record 1 of Set 6 | icod de los vinos
# Processing Record 2 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 3 of Set 6 | lexington
# Processing Record 4 of Set 6 | lebu
# Processing Record 5 of Set 6 | goderich
# Processing Record 6 of Set 6 | portland
# Processing Record 7 of Set 6 | itaituba
# Processing Record 8 of Set 6 | ambovombe
# Processing Record 9 of Set 6 | hamilton
# Processing Record 10 of Set 6 | okoneshnikovo
# Processing Record 11 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 12 of Set 6 | tyukalinsk
# Processing Record 13 of Set 6 | severo-kurilsk
# Processing Record 14 of Set 6 | denpasar
# Processing Record 15 of Set 6 | naze
# Processing Record 16 of Set 6 | abonnema
# Processing Record 17 of Set 6 | richards bay
# Processing Record 18 of Set 6 | kesinga
# Processing Record 19 of Set 6 | rozhdestveno
# Processing Record 20 of Set 6 | sao pedro do piaui
# Processing Record 21 of Set 6 | mount pleasant
# Processing Record 22 of Set 6 | sidi ali
# Processing Record 23 of Set 6 | temaraia
# City not found. Skipping...
# Processing Record 24 of Set 6 | sinazongwe
# Processing Record 25 of Set 6 | seydisehir
# Processing Record 26 of Set 6 | buraydah
# Processing Record 27 of Set 6 | chokurdakh
# Processing Record 28 of Set 6 | riyadh
# Processing Record 29 of Set 6 | grand gaube
# Processing Record 30 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 31 of Set 6 | kruisfontein
# Processing Record 32 of Set 6 | hobyo
# Processing Record 33 of Set 6 | alice springs
# Processing Record 34 of Set 6 | talcahuano
# Processing Record 35 of Set 6 | ponta delgada
# Processing Record 36 of Set 6 | kachug
# Processing Record 37 of Set 6 | san andres
# Processing Record 38 of Set 6 | surgut
# Processing Record 39 of Set 6 | coos bay
# Processing Record 40 of Set 6 | nome
# Processing Record 41 of Set 6 | tuatapere
# Processing Record 42 of Set 6 | westerland
# Processing Record 43 of Set 6 | haines junction
# Processing Record 44 of Set 6 | tilichiki
# Processing Record 45 of Set 6 | valparaiso
# Processing Record 46 of Set 6 | norrtalje
# Processing Record 47 of Set 6 | port lincoln
# Processing Record 48 of Set 6 | rocha
# Processing Record 49 of Set 6 | bend
# Processing Record 0 of Set 7 | kuryk
# Processing Record 1 of Set 7 | dikson
# Processing Record 2 of Set 7 | bundaberg
# Processing Record 3 of Set 7 | champerico
# Processing Record 4 of Set 7 | vila franca do campo
# Processing Record 5 of Set 7 | san remigio
# Processing Record 6 of Set 7 | tautira
# Processing Record 7 of Set 7 | banda aceh
# Processing Record 8 of Set 7 | axim
# Processing Record 9 of Set 7 | barrow
# Processing Record 10 of Set 7 | makat
# Processing Record 11 of Set 7 | den helder
# Processing Record 12 of Set 7 | vila
# Processing Record 13 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 14 of Set
of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 42 of Set 8 | pochutla
# Processing Record 43 of Set 8 | oktyabrskoye
# Processing Record 44 of Set 8 | fort nelson
# Processing Record 45 of Set 8 | havoysund
# Processing Record 46 of Set 8 | kollam
# Processing Record 47 of Set 8 | jau
# Processing Record 48 of Set 8 | manado
# Processing Record 49 of Set 8 | rantoul
# Processing Record 0 of Set 9 | tahta
# Processing Record 1 of Set 9 | seaford
# Processing Record 2 of Set 9 | arica
# Processing Record 3 of Set 9 | vanavara
# Processing Record 4 of Set 9 | mount isa
# Processing Record 5 of Set 9 | batangafo
# Processing Record 6 of Set 9 | ambon
# Processing Record 7 of Set 9 | lerwick
# Processing Record 8 of Set 9 | muros
# Processing Record 9 of Set 9 | bustamante
# Processing Record 10 of Set 9 | saint-pierre
# Processing Record 11 of Set 9 | sterling
# Processing Record 12 of Set 9 | tutoia
# Processing Record 13 of Set 9 | noumea
# Processing Record 14 of Set 9 | rio gallegos
# Processing Record 15 of Set 9 | atocha
# Processing Record 16 of Set 9 | guelengdeng
# City not found. Skipping...
# Processing Record 17 of Set 9 | naryan-mar
# Processing Record 18 of Set 9 | huicungo
# Processing Record 19 of Set 9 | tucuma
# Processing Record 20 of Set 9 | devils lake
# Processing Record 21 of Set 9 | serov
# Processing Record 22 of Set 9 | bajo baudo
# City not found. Skipping...
# Processing Record 23 of Set 9 | acarau
# Processing Record 24 of Set 9 | yarensk
# Processing Record 25 of Set 9 | farafangana
# Processing Record 26 of Set 9 | baran
# Processing Record 27 of Set 9 | georgetown
# Processing Record 28 of Set 9 | bambanglipuro
# Processing Record 29 of Set 9 | les cayes
# Processing Record 30 of Set 9 | ahuimanu
# Processing Record 31 of Set 9 | eskasem
# City not found. Skipping...
# Processing Record 32 of Set 9 | nelson bay
# Processing Record 33 of Set 9 | norman wells
# Processing Record 34 of Set 9 | kysyl-syr
# Processing Record 35 of Set 9 | port hardy
# Processing Record 36 of Set 9 | manhattan
# Processing Record 37 of Set 9 | odessa
# Processing Record 38 of Set 9 | avera
# Processing Record 39 of Set 9 | rengo
# Processing Record 40 of Set 9 | emet
# Processing Record 41 of Set 9 | pavlodar
# Processing Record 42 of Set 9 | jieshi
# Processing Record 43 of Set 9 | lalitpur
# Processing Record 44 of Set 9 | san juan
# Processing Record 45 of Set 9 | nizwa
# Processing Record 46 of Set 9 | the pas
# Processing Record 47 of Set 9 | paamiut
# Processing Record 48 of Set 9 | aneho
# Processing Record 49 of Set 9 | stornoway
# Processing Record 0 of Set 10 | mooi river
# City not found. Skipping...
# Processing Record 1 of Set 10 | lorengau
# Processing Record 2 of Set 10 | suhut
# Processing Record 3 of Set 10 | bodden town
# Processing Record 4 of Set 10 | ocampo
# Processing Record 5 of Set 10 | challapata
# Processing Record 6 of Set 10 | damietta
# Processing Record 7 of Set 10 | pitimbu
# Processing Record 8 of Set 10 | zharkent
# Processing Record 9 of Set 10 | quimper
# Processing Record 10 of Set 10 | rawah
# Processing Record 11 of Set 10 | alekseyevskaya
# Processing Record 12 of Set 10 | mehamn
# Processing Record 13 of Set 10 | swan hill
# Processing Record 14 of Set 10 | slave lake
# Processing Record 15 of Set 10 | jabinyanah
# Processing Record 16 of Set 10 | khajuraho
# Processing Record 17 of Set 10 | izhma
# Processing Record 18 of Set 10 | evensk
# Processing Record 19 of Set 10 | mayo
# Processing Record 20 of Set 10 | carauari
# Processing Record 21 of Set 10 | korla
# Processing Record 22 of Set 10 | stolin
# Processing Record 23 of Set 10 | vyazemskiy
# Processing Record 24 of Set 10 | santander
# Processing Record 25 of Set 10 | sampit
# Processing Record 26 of Set 10 | namtsy
# Processing Record 27 of Set 10 | chimbote
# Processing Record 28 of Set 10 | manalurpet
# City not found. Skipping...
# Processing Record 29 of Set 10 | alanya
# Processing Record 30 of Set 10 | manta
# Processing Record 31 of Set 10 | berdigestyakh
# Processing Record 32 of Set 10 | shache
# Processing Record 33 of Set 10 | darhan
# Processing Record 34 of Set 10 | high level
# Processing Record 35 of Set 10 | yerofey pavlovich
# Processing Record 36 of Set 10 | majene
# Processing Record 37 of Set 10 | labuhan
# Processing Record 38 of Set 10 | katherine
# Processing Record 39 of Set 10 | fairbanks
# Processing Record 40 of Set 10 | samarinda
# Processing Record 41 of Set 10 | pucallpa
# Processing Record 42 of Set 10 | sitka
# Processing Record 43 of Set 10 | chuy
# Processing Record 44 of Set 10 | ardakan
# Processing Record 45 of Set 10 | san martino buon albergo
# Processing Record 46 of Set 10 | stonewall
# Processing Record 47 of Set 10 | panama city
# Processing Record 48 of Set 10 | half moon bay
# Processing Record 49 of Set 10 | teknaf
# Processing Record 0 of Set 11 | zhigansk
# Processing Record 1 of Set 11 | krasnyy chikoy
# Processing Record 2 of Set 11 | marialva
# Processing Record 3 of Set 11 | urumqi
# Processing Record 4 of Set 11 | guerrero negro
# Processing Record 5 of Set 11 | coahuayana
# Processing Record 6 of Set 11 | rio grande
# Processing Record 7 of Set 11 | puerto escondido
# Processing Record 8 of Set 11 | vermilion
# Processing Record 9 of Set 11 | xichang
# Processing Record 10 of Set 11 | we
# City not found. Skipping...
# Processing Record 11 of Set 11 | ust-nera
# Processing Record 12 of Set 11 | ituporanga
# Processing Record 13 of Set 11 | arlit
# Processing Record 14 of Set 11 | talnakh
# Processing Record 15 of Set 11 | paracuru
# Processing Record 16 of Set 11 | imbituba
# Processing Record 17 of Set 11 | bengkulu
# Processing Record 18 of Set 11 | sovetskiy
# Processing Record 19 of Set 11 | srednekolymsk
# Processing Record 20 of Set 11 | kieta
# Processing Record 21 of Set 11 | nara
# Processing Record 22 of Set 11 | waingapu
# Processing Record 23 of Set 11 | nanlong
# Processing Record 24 of Set 11 | mogadouro
# Processing Record 25 of Set 11 | dondo
# Processing Record 26 of Set 11 | port-gentil
# Processing Record 27 of Set 11 | gilgit
# Processing Record 28 of Set 11 | winneba
# Processing Record 29 of Set 11 | pampierstad
# Processing Record 30 of Set 11 | nemuro
# Processing Record 31 of Set 11 | berlevag
# Processing Record 32 of Set 11 | dawlatabad
# Processing Record 33 of Set 11 | hovd
# Processing Record 34 of Set 11 | sao joao da barra
# Processing Record 35 of Set 11 | clearlake
# Processing Record 36 of Set 11 | tahara
# Processing Record 37 of Set 11 | penzance
# Processing Record 38 of Set 11 | vangaindrano
# Processing Record 39 of Set 11 | kurilsk
# Processing Record 40 of Set 11 | bonavista
# Processing Record 41 of Set 11 | kununurra
# Processing Record 42 of Set 11 | akom
# Processing Record 43 of Set 11 | broken hill
# Processing Record 44 of Set 11 | hirara
# Processing Record 45 of Set 11 | ostrovnoy
# Processing Record 46 of Set 11 | mazagao
# Processing Record 47 of Set 11 | kiruna
# Processing Record 48 of Set 11 | acari
# Processing Record 49 of Set 11 | mana
# Processing Record 0 of Set 12 | tura
# Processing Record 1 of Set 12 | semnan
# Processing Record 2 of Set 12 | mpongwe
# Processing Record 3 of Set 12 | skagastrond
# City not found. Skipping...
# Processing Record 4 of Set 12 | hurghada
# Processing Record 5 of Set 12 | ussel
# Processing Record 6 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 7 of Set 12 | tual
# Processing Record 8 of Set 12 | mitry-mory
# Processing Record 9 of Set 12 | diamantino
# Processing Record 10 of Set 12 | ha
# City not found. Skipping...
# Processing Record 11 of Set 12 | moosburg
# Processing Record 12 of Set 12 | novobirilyussy
# Processing Record 13 of Set 12 | wasilla
# Processing Record 14 of Set 12 | praia
# Processing Record 15 of Set 12 | kuytun
# Processing Record 16 of Set 12 | ixtapa
# Processing Record 17 of Set 12 | dingle
# Processing Record 18 of Set 12 | taoudenni
# Processing Record 19 of Set 12 | gornopravdinsk
# Processing Record 20 of Set 12 | halifax
# Processing Record 21 of Set 12 | greenwood
# Processing Record 22 of Set 12 | new ulm
# Processing Record 23 of Set 12 | saraikela
# Processing Record 24 of Set 12 | baykit
# Processing Record 25 of Set 12 | chernyshevskiy
# Processing Record 26 of Set 12 | ketchikan
# Processing Record 27 of Set 12 | kapiri mposhi
# Processing Record 28 of Set 12 | jumla
# Processing Record 29 of Set 12 | juruti
# Processing Record 30 of Set 12 | necochea
# Processing Record 31 of Set 12 | cabanas
# Processing Record 32 of Set 12 | pacific grove
# Processing Record 33 of Set 12 | werda
# Processing Record 34 of Set 12 | zhuanghe
# Processing Record 35 of Set 12 | fortuna
# Processing Record 36 of Set 12 | leningradskiy
# Processing Record 37 of Set 12 | qingdao
# Processing Record 38 of Set 12 | ye
# City not found. Skipping...
# Processing Record 39 of Set 12 | trincomalee
# Processing Record 40 of Set 12 | ituni
# City not found. Skipping...
# Processing Record 41 of Set 12 | adra
# Processing Record 42 of Set 12 | porbandar
# Processing Record 43 of Set 12 | colares
# Processing Record 44 of Set 12 | namatanai
# Processing Record 45 of Set 12 | tanda
# Processing Record 46 of Set 12 | alghero
# Processing Record 47 of Set 12 | pathein
# Processing Record 48 of Set 12 | yarada
# Processing Record 49 of Set 12 | larsnes
# Processing Record 0 of Set 13 | seymchan
# Processing Record 1 of Set 13 | stryn
# Processing Record 2 of Set 13 | cristalina
# Processing Record 3 of Set 13 | saryshagan
# City not found. Skipping...
# Processing Record 4 of Set 13 | strezhevoy
# Processing Record 5 of Set 13 | bilma
# Processing Record 6 of Set 13 | porto santo
# Processing Record 7 of Set 13 | kutum
# Processing Record 8 of Set 13 | sawakin
# Processing Record 9 of Set 13 | mumford
# Processing Record 10 of Set 13 | omboue
# Processing Record 11 of Set 13 | bambous virieux
# Processing Record 12 of Set 13 | charters towers
# Processing Record 13 of Set 13 | two rivers
# Processing Record 14 of Set 13 | port moresby
# Processing Record 15 of Set 13 | alihe
# Processing Record 16 of Set 13 | statesboro
# Processing Record 17 of Set 13 | meulaboh
# Processing Record 18 of Set 13 | marsa matruh
# Processing Record 19 of Set 13 | lata
# Processing Record 20 of Set 13 | inhambane
# Processing Record 21 of Set 13 | lavumisa
# Processing Record 22 of Set 13 | kayes
# Processing Record 23 of Set 13 | te anau
# Processing Record 24 of Set 13 | xingcheng
# Processing Record 25 of Set 13 | rognan
# Processing Record 26 of Set 13 | ust-kuyga
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_weather
# Out:
# {'coord': {'lon': 135.6, 'lat': 70.0167},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': -31.13,
#   'feels_like': -38.13,
#   'temp_min': -31.13,
#   'temp_max': -31.13,
#   'pressure': 1002,
#   'humidity': 90,
#   'sea_level': 1002,
#   'grnd_level': 993},
#  'visibility': 10000,
#  'wind': {'speed': 3.88, 'deg': 184, 'gust': 5.17},
#  'clouds': {'all': 91},
#  'dt': 1677886235,
#  'sys': {'country': 'RU', 'sunrise': 1677881687, 'sunset': 1677917072},
#  'timezone': 36000,
#  'id': 2013921,
#  'name': 'Ust-Kuyga',
#  'cod': 200}

# %%
# Set the API base URL
url = # YOUR CODE HERE

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = # YOUR CODE HERE
    
    # Log the url, record, and set numbers
    # print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = # YOUR CODE HERE

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = # YOUR CODE HERE
        city_lng = # YOUR CODE HERE
        city_max_temp = # YOUR CODE HERE
        city_humidity = # YOUR CODE HERE
        city_clouds = # YOUR CODE HERE
        city_wind = # YOUR CODE HERE
        city_country = # YOUR CODE HERE
        city_date = # YOUR CODE HERE

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        # print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
#   File "/var/folders/hx/6hnx1rtx15gcdgvwwgxpg9_80000gn/T/ipykernel_3708/1497952295.py", line 2
#     url = # YOUR CODE HERE
#           ^
# SyntaxError: invalid syntax

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          581
# Lat           581
# Lng           581
# Max Temp      581
# Humidity      581
# Cloudiness    581
# Wind Speed    581
# Country       581
# Date          581
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          hauterive  46.0901    3.4459      6.42        85         100
# 1  fortuna foothills  32.6578 -114.4119     19.56        31           0
# 2            rikitea -23.1203 -134.9692     26.80        70          48
# 3        corn island  12.1694  -83.0418     26.41        76          42
# 4           olafsvik  64.8945  -23.7142      4.32        83         100
#
#    Wind Speed Country        Date
# 0        0.97      FR  1677885491
# 1        2.57      US  1677885492
# 2        4.87      PF  1677884910
# 3        5.72      NI  1677885496
# 4        5.16      IS  1677885289

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                hauterive  46.0901    3.4459      6.42        85         100
# 1        fortuna foothills  32.6578 -114.4119     19.56        31           0
# 2                  rikitea -23.1203 -134.9692     26.80        70          48
# 3              corn island  12.1694  -83.0418     26.41        76          42
# 4                 olafsvik  64.8945  -23.7142      4.32        83         100
#
#          Wind Speed Country        Date
# City_ID
# 0              0.97      FR  1677885491
# 1              2.57      US  1677885492
# 2              4.87      PF  1677884910
# 3              5.72      NI  1677885496
# 4              5.16      IS  1677885289

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'], city_data_df['Max Temp'], color = 'c', edgecolor = 'blue', alpha = 0.9)

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.title('City Latitude vs. Max Temperature (2022-10-28)')
plt.grid()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'], city_data_df['Humidity'], color = 'c', edgecolor = 'blue', alpha = 0.9)

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('City Latitude vs. Humidity (2022-10-18)')
plt.grid()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'], city_data_df['Cloudiness'], color = 'c', edgecolor = 'blue', alpha = 0.9)

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('City Latitude vs. Cloudiness (2022-10-18)')
plt.grid()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'], city_data_df['Wind Speed'], color = 'c', edgecolor = 'blue', alpha = 0.9)

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.title('City Latitude vs. Wind Speed (2022-10-18)')
plt.grid()


# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linear_regression(x, y, ylabel, title, a, b):
   
    (slope, intercept, r_value, p_value, strerr) = linregress(x, y)
    plt.scatter(x, y)
    plt.xlabel("Latitude")
    plt.ylabel(ylabel)
    plt.title(title)
    fit = (slope * x) + intercept
    plt.plot(x, fit, "r--")
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.annotate(line_eq, fontsize=15, color="red", xy = (a, b))
    print(f"The r-value is: {r_value}")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                hauterive  46.0901    3.4459      6.42        85         100
# 1        fortuna foothills  32.6578 -114.4119     19.56        31           0
# 3              corn island  12.1694  -83.0418     26.41        76          42
# 4                 olafsvik  64.8945  -23.7142      4.32        83         100
# 6                    vardo  70.3705   31.1107      0.99        80          40
#
#          Wind Speed Country        Date
# City_ID
# 0              0.97      FR  1677885491
# 1              2.57      US  1677885492
# 3              5.72      NI  1677885496
# 4              5.16      IS  1677885289
# 6              6.69      NO  1677885161

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] <= 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2             rikitea -23.1203 -134.9692     26.80        70          48
# 5           busselton -33.6500  115.3333     19.87        65          80
# 9        punta arenas -53.1500  -70.9167      5.06        87          75
# 11            tanhacu -14.0214  -41.2481     25.82        55           4
# 17            mataura -46.1927  168.8643     13.04        48          99
#
#          Wind Speed Country        Date
# City_ID
# 2              4.87      PF  1677884910
# 5              5.15      AU  1677884980
# 9              8.23      CL  1677885504
# 11             4.20      BR  1677885506
# 17             2.13      NZ  1677884919

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
linear_regression(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'], "Max Temperature (C)", "Northern Hemisphere Latitude vs Max Temperature", 0, 0)
# Out:
# The r-value is: -0.8938020273679885

# %%
# Linear regression on Southern Hemisphere
linear_regression(southern_hemi_df['Lat'], southern_hemi_df['Max Temp'], "Max Temperature (C)", "Southern Hemisphere Latitude vs Max Temperature", -40, 10)
# Out:
# The r-value is: 0.5543334932875706

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regression(northern_hemi_df['Lat'], northern_hemi_df['Humidity'], "Humidity (%)", "Northern Hemisphere Latitude vs Humidity", 40, 40)
# Out:
# The r-value is: 0.41335418580007965

# %%
# Southern Hemisphere
linear_regression(southern_hemi_df['Lat'], southern_hemi_df['Humidity'], "Humidity (%)", "Southern Hemisphere Latitude vs Humidity", -30, 55)
# Out:
# The r-value is: 0.3316841494263491

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regression(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'], "Cloudiness (%)", "Northern Hemisphere Latitude vs Cloudiness", 50, 50)
# Out:
# The r-value is: 0.38037544258258005

# %%
# Southern Hemisphere
linear_regression(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'], "Cloudiness (%)", "Southern Hemisphere Latitude vs Cloudiness", -50, 60)
# Out:
# The r-value is: 0.2873708777142346

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regression(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'], "Wind Speed (m/s)", "Northern Hemisphere Latitude vs Wind Speed", 10, 12.5)
# Out:
# The r-value is: 0.0519005890394977

# %%
# Southern Hemisphere
linear_regression(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'], "Wind Speed (m/s)", "Southern Hemisphere Latitude vs Wind Speed", -45, 7.5)
# Out:
# The r-value is: -0.23502774648320235

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
